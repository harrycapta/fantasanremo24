# %%
# %reload_ext nb_black

# %%
from bs4 import BeautifulSoup
from lxml import etree
import requests
from lxml.etree import tostring
from collections import defaultdict

# %%
mapping = {
    "alessandra amoroso": "fino a qui",
    "alfa'": "vai!",
    "angelina mango": "la noia",
    "annalisa": "sinceramente",
    "bigmama": "la rabbia non ti basta",
    "bnkr44": "governo punk",
    "clara": "diamanti grezzi",
    "dargen d'amico": "onda alta",
    "diodato": "ti muovi",
    "emma": "apnea",
    "fiorella mannoia": "mariposa",
    "fred de palma": "il cielo non ci vuole",
    "gazzelle": "tutto qui",
    "geolier": "I p' me, tu p' te",
    "ghali": "casa mia",
    "il tre": "fragili",
    "il volo": "capolavoro",
    "irama": "tu no",
    "la sad": "autodistruttivo",
    "loredana berte": "pazza",
    "mahmood": "tuta gold",
    "mannini": "spettacolare",
    "mr.rain": "due altalene",
    "negramaro": "ricominciamo tutto",
    "renga e nek": "pazzo di te",
    "ricchi e poveri": "ma non tutta la vita",
    "rose villain": "click boom!",
    "sangiovanni": "finiscimi",
    "santi francesi": "l'amore in bocca",
    "the kolors": "un ragazzo una ragazza"
}

# %%
bets_map = defaultdict(list)

# %% [markdown]
# ### Unibet

# %%
bets_page = open("bets.html", "r").read()
bets_soup = BeautifulSoup(bets_page, "html.parser")

# %%
singers = []
bets = []
dom = etree.HTML(str(bets_soup))
singers_rows = dom.xpath("//span[@class='KambiBC-outcomes-list__label']")
bets_rows = dom.xpath("//div[@class='sc-iBYQkv hYDhjM']")
for singer_row in singers_rows:
    singer = singer_row.xpath("span/text()")[0].lower().strip()
    if singer in mapping:
        singer = mapping[singer]
    singers.append(singer)
for bet_row in bets_rows:
    bet = bet_row.xpath("text()")[0].lower().strip()
    bets.append(bet)
for s,b in zip(singers,bets):
    bets_map[s].append(float(b))

print(singers,bets)
# Out:
# ["I p' me, tu p' te", 'fino a qui', 'sinceramente', 'ricominciamo tutto', 'la noia', 'capolavoro', 'tuta gold', 'ti muovi', 'tu no', 'apnea', 'diamanti grezzi', 'mariposa', 'mr. rain', 'un ragazzo una ragazza', 'casa mia', 'tutto qui', 'pazzo di te', "l'amore in bocca", 'finiscimi', 'alfa', 'la rabbia non ti basta', 'dargen d amico', 'fragili', 'pazza', 'click boom!', 'governo punk', 'autodistruttivo', 'il cielo non ci vuole', 'maninni', 'ma non tutta la vita'] ['3.00', '4.50', '6.00', '9.00', '10.00', '13.00', '13.00', '15.00', '15.00', '21.00', '26.00', '26.00', '26.00', '26.00', '31.00', '34.00', '34.00', '34.00', '41.00', '51.00', '51.00', '51.00', '51.00', '51.00', '51.00', '67.00', '67.00', '81.00', '81.00', '101.0']

# %% [markdown]
# ### Goldbet

# %%
bets_page = open("bets_2.html", "r").read()
bets_soup = BeautifulSoup(bets_page, "html.parser")

# %%
dom = etree.HTML(str(bets_soup))
rows_s = dom.xpath("//td[@class='match aview']")
rows_b = dom.xpath("//td[@class='match aview']")
singers = []
bets = []
for row in rows_s:
    try:
        singer = row.xpath("span[@class='singer']/text()")[0].lower().strip()
        if singer in mapping:
            singer = mapping[singer]
        singers.append(singer)
    except IndexError:
        pass
    print(singer)
for row in rows_b:
    if row.xpath("span[@class='bet']/text()"):
        try:
            bet = float(row.xpath("span[@class='bet']/text()")[0].lower().strip())
            print(bet)
            bets.append(bet)
            print(bets)
        except ValueError:
            pass
for s,b in zip(singers,bets):
    bets_map[s].append(float(b))
# Out:
# fino a qui
# I p' me, tu p' te
# sinceramente
# la noia
# tuta gold
# ricominciamo tutto
# capolavoro
# tu no
# ti muovi
# un ragazzo una ragazza
# apnea
# mariposa
# mr rain
# tutto qui
# finiscimi
# dargen d amico
# pazzo di te
# casa mia
# alfa
# click boom!
# il cielo non ci vuole
# big mama
# pazza
# ma non tutta la vita
# fragili
# maninni
# autodistruttivo
# l'amore in bocca
# 4.0
# [4.0]
# 4.0
# [4.0, 4.0]
# 7.0
# [4.0, 4.0, 7.0]
# 7.5
# [4.0, 4.0, 7.0, 7.5]
# 11.0
# [4.0, 4.0, 7.0, 7.5, 11.0]
# 11.0
# [4.0, 4.0, 7.0, 7.5, 11.0, 11.0]
# 16.0
# [4.0, 4.0, 7.0, 7.5, 11.0, 11.0, 16.0]
# 16.0
# [4.0, 4.0, 7.0, 7.5, 11.0, 11.0, 16.0, 16.0]
# 16.0
# [4.0, 4.0, 7.0, 7.5, 11.0, 11.0, 16.0, 16.0, 16.0]
# 21.0
# [4.0, 4.0, 7.0, 7.5, 11.0, 11.0, 16.0, 16.0, 16.0, 21.0]
# 21.0
# [4.0, 4.0, 7.0, 7.5, 11.0, 11.0, 16.0, 16.0, 16.0, 21.0, 21.0]
# 21.0
# [4.0, 4.0, 7.0, 7.5, 11.0, 11.0, 16.0, 16.0, 16.0, 21.0, 21.0, 21.0]
# 26.0
# [4.0, 4.0, 7.0, 7.5, 11.0, 11.0, 16.0, 16.0, 16.0, 21.0, 21.0, 21.0, 26.0]
# 31.0
# [4.0, 4.0, 7.0, 7.5, 11.0, 11.0, 16.0, 16.0, 16.0, 21.0, 21.0, 21.0, 26.0, 31.0]
# 31.0
# [4.0, 4.0, 7.0, 7.5, 11.0, 11.0, 16.0, 16.0, 16.0, 21.0, 21.0, 21.0, 26.0, 31.0, 31.0]
# 36.0
# [4.0, 4.0, 7.0, 7.5, 11.0, 11.0, 16.0, 16.0, 16.0, 21.0, 21.0, 21.0, 26.0, 31.0, 31.0, 36.0]
# 36.0
# [4.0, 4.0, 7.0, 7.5, 11.0, 11.0, 16.0, 16.0, 16.0, 21.0, 21.0, 21.0, 26.0, 31.0, 31.0, 36.0, 36.0]
# 36.0
# [4.0, 4.0, 7.0, 7.5, 11.0, 11.0, 16.0, 16.0, 16.0, 21.0, 21.0, 21.0, 26.0, 31.0, 31.0, 36.0, 36.0, 36.0]
# 51.0
# [4.0, 4.0, 7.0, 7.5, 11.0, 11.0, 16.0, 16.0, 16.0, 21.0, 21.0, 21.0, 26.0, 31.0, 31.0, 36.0, 36.0, 36.0, 51.0]
# 51.0
# [4.0, 4.0, 7.0, 7.5, 11.0, 11.0, 16.0, 16.0, 16.0, 21.0, 21.0, 21.0, 26.0, 31.0, 31.0, 36.0, 36.0, 36.0, 51.0, 51.0]
# 51.0
# [4.0, 4.0, 7.0, 7.5, 11.0, 11.0, 16.0, 16.0, 16.0, 21.0, 21.0, 21.0, 26.0, 31.0, 31.0, 36.0, 36.0, 36.0, 51.0, 51.0, 51.0]
# 71.0
# [4.0, 4.0, 7.0, 7.5, 11.0, 11.0, 16.0, 16.0, 16.0, 21.0, 21.0, 21.0, 26.0, 31.0, 31.0, 36.0, 36.0, 36.0, 51.0, 51.0, 51.0, 71.0]
# 71.0
# [4.0, 4.0, 7.0, 7.5, 11.0, 11.0, 16.0, 16.0, 16.0, 21.0, 21.0, 21.0, 26.0, 31.0, 31.0, 36.0, 36.0, 36.0, 51.0, 51.0, 51.0, 71.0, 71.0]
# 101.0
# [4.0, 4.0, 7.0, 7.5, 11.0, 11.0, 16.0, 16.0, 16.0, 21.0, 21.0, 21.0, 26.0, 31.0, 31.0, 36.0, 36.0, 36.0, 51.0, 51.0, 51.0, 71.0, 71.0, 101.0]
# 101.0
# [4.0, 4.0, 7.0, 7.5, 11.0, 11.0, 16.0, 16.0, 16.0, 21.0, 21.0, 21.0, 26.0, 31.0, 31.0, 36.0, 36.0, 36.0, 51.0, 51.0, 51.0, 71.0, 71.0, 101.0, 101.0]
# 101.0
# [4.0, 4.0, 7.0, 7.5, 11.0, 11.0, 16.0, 16.0, 16.0, 21.0, 21.0, 21.0, 26.0, 31.0, 31.0, 36.0, 36.0, 36.0, 51.0, 51.0, 51.0, 71.0, 71.0, 101.0, 101.0, 101.0]
# 101.0
# [4.0, 4.0, 7.0, 7.5, 11.0, 11.0, 16.0, 16.0, 16.0, 21.0, 21.0, 21.0, 26.0, 31.0, 31.0, 36.0, 36.0, 36.0, 51.0, 51.0, 51.0, 71.0, 71.0, 101.0, 101.0, 101.0, 101.0]
# 16.0
# [4.0, 4.0, 7.0, 7.5, 11.0, 11.0, 16.0, 16.0, 16.0, 21.0, 21.0, 21.0, 26.0, 31.0, 31.0, 36.0, 36.0, 36.0, 51.0, 51.0, 51.0, 71.0, 71.0, 101.0, 101.0, 101.0, 101.0, 16.0]

# %%
bets_map
# Out:
# defaultdict(list,
#             {"I p' me, tu p' te": [3.0, 4.0],
#              'fino a qui': [4.5, 4.0],
#              'sinceramente': [6.0, 7.0],
#              'ricominciamo tutto': [9.0, 11.0],
#              'la noia': [10.0, 7.5],
#              'capolavoro': [13.0, 16.0],
#              'tuta gold': [13.0, 11.0],
#              'ti muovi': [15.0, 16.0],
#              'tu no': [15.0, 16.0],
#              'apnea': [21.0, 21.0],
#              'diamanti grezzi': [26.0],
#              'mariposa': [26.0, 21.0],
#              'mr. rain': [26.0],
#              'un ragazzo una ragazza': [26.0, 21.0],
#              'casa mia': [31.0, 36.0],
#              'tutto qui': [34.0, 31.0],
#              'pazzo di te': [34.0, 36.0],
#              "l'amore in bocca": [34.0, 16.0],
#              'finiscimi': [41.0, 31.0],
#              'alfa': [51.0, 51.0],
#              'la rabbia non ti basta': [51.0],
#              'dargen d amico': [51.0, 36.0],
#              'fragili': [51.0, 101.0],
#              'pazza': [51.0, 71.0],
#              'click boom!': [51.0, 51.0],
#              'governo punk': [67.0],
#              'autodistruttivo': [67.0, 101.0],
#              'il cielo non ci vuole': [81.0, 51.0],
#              'maninni': [81.0, 101.0],
#              'ma non tutta la vita': [101.0, 101.0],
#              'mr rain': [26.0],
#              'big mama': [71.0]})

# %%
singers_page = open("singers.html", "r").read()
soup_singers = BeautifulSoup(singers_page, "html.parser")

# %%
singers_map = {}

# %%
dom_singers = etree.HTML(str(soup_singers))
rows_bets = dom_singers.xpath("//span[@class='MuiTypography-root MuiTypography-body1 css-rfihay']")
rows_singers = dom_singers.xpath("//h6[@class='MuiTypography-root MuiTypography-subtitle1 css-122mmfo']")
singers = []
bets = []
for row in rows_singers:
    singer = row.xpath("text()")[0].lower().strip()
    singers.append(singer)
    print(singers)

for row in rows_bets:
    bet = row.xpath("text()")[0].lower().strip()
    bets.append(float(bet))
    print(bets)
# Out:
# ['alessandra amoroso']
# ['alessandra amoroso', 'alfa']
# ['alessandra amoroso', 'alfa', 'angelina mango']
# ['alessandra amoroso', 'alfa', 'angelina mango', 'annalisa']
# ['alessandra amoroso', 'alfa', 'angelina mango', 'annalisa', 'bigmama']
# ['alessandra amoroso', 'alfa', 'angelina mango', 'annalisa', 'bigmama', 'bnkr44']
# ['alessandra amoroso', 'alfa', 'angelina mango', 'annalisa', 'bigmama', 'bnkr44', 'clara']
# ['alessandra amoroso', 'alfa', 'angelina mango', 'annalisa', 'bigmama', 'bnkr44', 'clara', 'dargen d amico']
# ['alessandra amoroso', 'alfa', 'angelina mango', 'annalisa', 'bigmama', 'bnkr44', 'clara', 'dargen d amico', 'diodato']
# ['alessandra amoroso', 'alfa', 'angelina mango', 'annalisa', 'bigmama', 'bnkr44', 'clara', 'dargen d amico', 'diodato', 'emma']
# ['alessandra amoroso', 'alfa', 'angelina mango', 'annalisa', 'bigmama', 'bnkr44', 'clara', 'dargen d amico', 'diodato', 'emma', 'fiorella mannoia']
# ['alessandra amoroso', 'alfa', 'angelina mango', 'annalisa', 'bigmama', 'bnkr44', 'clara', 'dargen d amico', 'diodato', 'emma', 'fiorella mannoia', 'fred de palma']
# ['alessandra amoroso', 'alfa', 'angelina mango', 'annalisa', 'bigmama', 'bnkr44', 'clara', 'dargen d amico', 'diodato', 'emma', 'fiorella mannoia', 'fred de palma', 'gazzelle']
# ['alessandra amoroso', 'alfa', 'angelina mango', 'annalisa', 'bigmama', 'bnkr44', 'clara', 'dargen d amico', 'diodato', 'emma', 'fiorella mannoia', 'fred de palma', 'gazzelle', 'geolier']
# ['alessandra amoroso', 'alfa', 'angelina mango', 'annalisa', 'bigmama', 'bnkr44', 'clara', 'dargen d amico', 'diodato', 'emma', 'fiorella mannoia', 'fred de palma', 'gazzelle', 'geolier', 'ghali']
# ['alessandra amoroso', 'alfa', 'angelina mango', 'annalisa', 'bigmama', 'bnkr44', 'clara', 'dargen d amico', 'diodato', 'emma', 'fiorella mannoia', 'fred de palma', 'gazzelle', 'geolier', 'ghali', 'il tre']
# ['alessandra amoroso', 'alfa', 'angelina mango', 'annalisa', 'bigmama', 'bnkr44', 'clara', 'dargen d amico', 'diodato', 'emma', 'fiorella mannoia', 'fred de palma', 'gazzelle', 'geolier', 'ghali', 'il tre', 'il volo']
# ['alessandra amoroso', 'alfa', 'angelina mango', 'annalisa', 'bigmama', 'bnkr44', 'clara', 'dargen d amico', 'diodato', 'emma', 'fiorella mannoia', 'fred de palma', 'gazzelle', 'geolier', 'ghali', 'il tre', 'il volo', 'irama']
# ['alessandra amoroso', 'alfa', 'angelina mango', 'annalisa', 'bigmama', 'bnkr44', 'clara', 'dargen d amico', 'diodato', 'emma', 'fiorella mannoia', 'fred de palma', 'gazzelle', 'geolier', 'ghali', 'il tre', 'il volo', 'irama', 'la sad']
# ['alessandra amoroso', 'alfa', 'angelina mango', 'annalisa', 'bigmama', 'bnkr44', 'clara', 'dargen d amico', 'diodato', 'emma', 'fiorella mannoia', 'fred de palma', 'gazzelle', 'geolier', 'ghali', 'il tre', 'il volo', 'irama', 'la sad', 'loredana berte']
# ['alessandra amoroso', 'alfa', 'angelina mango', 'annalisa', 'bigmama', 'bnkr44', 'clara', 'dargen d amico', 'diodato', 'emma', 'fiorella mannoia', 'fred de palma', 'gazzelle', 'geolier', 'ghali', 'il tre', 'il volo', 'irama', 'la sad', 'loredana berte', 'mahmood']
# ['alessandra amoroso', 'alfa', 'angelina mango', 'annalisa', 'bigmama', 'bnkr44', 'clara', 'dargen d amico', 'diodato', 'emma', 'fiorella mannoia', 'fred de palma', 'gazzelle', 'geolier', 'ghali', 'il tre', 'il volo', 'irama', 'la sad', 'loredana berte', 'mahmood', 'maninni']
# ['alessandra amoroso', 'alfa', 'angelina mango', 'annalisa', 'bigmama', 'bnkr44', 'clara', 'dargen d amico', 'diodato', 'emma', 'fiorella mannoia', 'fred de palma', 'gazzelle', 'geolier', 'ghali', 'il tre', 'il volo', 'irama', 'la sad', 'loredana berte', 'mahmood', 'maninni', 'mr.rain']
# ['alessandra amoroso', 'alfa', 'angelina mango', 'annalisa', 'bigmama', 'bnkr44', 'clara', 'dargen d amico', 'diodato', 'emma', 'fiorella mannoia', 'fred de palma', 'gazzelle', 'geolier', 'ghali', 'il tre', 'il volo', 'irama', 'la sad', 'loredana berte', 'mahmood', 'maninni', 'mr.rain', 'negramaro']
# ['alessandra amoroso', 'alfa', 'angelina mango', 'annalisa', 'bigmama', 'bnkr44', 'clara', 'dargen d amico', 'diodato', 'emma', 'fiorella mannoia', 'fred de palma', 'gazzelle', 'geolier', 'ghali', 'il tre', 'il volo', 'irama', 'la sad', 'loredana berte', 'mahmood', 'maninni', 'mr.rain', 'negramaro', 'renga e nek']
# ['alessandra amoroso', 'alfa', 'angelina mango', 'annalisa', 'bigmama', 'bnkr44', 'clara', 'dargen d amico', 'diodato', 'emma', 'fiorella mannoia', 'fred de palma', 'gazzelle', 'geolier', 'ghali', 'il tre', 'il volo', 'irama', 'la sad', 'loredana berte', 'mahmood', 'maninni', 'mr.rain', 'negramaro', 'renga e nek', 'ricchi e poveri']
# ['alessandra amoroso', 'alfa', 'angelina mango', 'annalisa', 'bigmama', 'bnkr44', 'clara', 'dargen d amico', 'diodato', 'emma', 'fiorella mannoia', 'fred de palma', 'gazzelle', 'geolier', 'ghali', 'il tre', 'il volo', 'irama', 'la sad', 'loredana berte', 'mahmood', 'maninni', 'mr.rain', 'negramaro', 'renga e nek', 'ricchi e poveri', 'rose villain']
# ['alessandra amoroso', 'alfa', 'angelina mango', 'annalisa', 'bigmama', 'bnkr44', 'clara', 'dargen d amico', 'diodato', 'emma', 'fiorella mannoia', 'fred de palma', 'gazzelle', 'geolier', 'ghali', 'il tre', 'il volo', 'irama', 'la sad', 'loredana berte', 'mahmood', 'maninni', 'mr.rain', 'negramaro', 'renga e nek', 'ricchi e poveri', 'rose villain', 'sangiovanni']
# ['alessandra amoroso', 'alfa', 'angelina mango', 'annalisa', 'bigmama', 'bnkr44', 'clara', 'dargen d amico', 'diodato', 'emma', 'fiorella mannoia', 'fred de palma', 'gazzelle', 'geolier', 'ghali', 'il tre', 'il volo', 'irama', 'la sad', 'loredana berte', 'mahmood', 'maninni', 'mr.rain', 'negramaro', 'renga e nek', 'ricchi e poveri', 'rose villain', 'sangiovanni', 'santi francesi']
# ['alessandra amoroso', 'alfa', 'angelina mango', 'annalisa', 'bigmama', 'bnkr44', 'clara', 'dargen d amico', 'diodato', 'emma', 'fiorella mannoia', 'fred de palma', 'gazzelle', 'geolier', 'ghali', 'il tre', 'il volo', 'irama', 'la sad', 'loredana berte', 'mahmood', 'maninni', 'mr.rain', 'negramaro', 'renga e nek', 'ricchi e poveri', 'rose villain', 'sangiovanni', 'santi francesi', 'the kolors']
# [23.0]
# [23.0, 20.0]
# [23.0, 20.0, 23.0]
# [23.0, 20.0, 23.0, 23.0]
# [23.0, 20.0, 23.0, 23.0, 17.0]
# [23.0, 20.0, 23.0, 23.0, 17.0, 16.0]
# [23.0, 20.0, 23.0, 23.0, 17.0, 16.0, 16.0]
# [23.0, 20.0, 23.0, 23.0, 17.0, 16.0, 16.0, 22.0]
# [23.0, 20.0, 23.0, 23.0, 17.0, 16.0, 16.0, 22.0, 21.0]
# [23.0, 20.0, 23.0, 23.0, 17.0, 16.0, 16.0, 22.0, 21.0, 23.0]
# [23.0, 20.0, 23.0, 23.0, 17.0, 16.0, 16.0, 22.0, 21.0, 23.0, 20.0]
# [23.0, 20.0, 23.0, 23.0, 17.0, 16.0, 16.0, 22.0, 21.0, 23.0, 20.0, 18.0]
# [23.0, 20.0, 23.0, 23.0, 17.0, 16.0, 16.0, 22.0, 21.0, 23.0, 20.0, 18.0, 19.0]
# [23.0, 20.0, 23.0, 23.0, 17.0, 16.0, 16.0, 22.0, 21.0, 23.0, 20.0, 18.0, 19.0, 22.0]
# [23.0, 20.0, 23.0, 23.0, 17.0, 16.0, 16.0, 22.0, 21.0, 23.0, 20.0, 18.0, 19.0, 22.0, 20.0]
# [23.0, 20.0, 23.0, 23.0, 17.0, 16.0, 16.0, 22.0, 21.0, 23.0, 20.0, 18.0, 19.0, 22.0, 20.0, 17.0]
# [23.0, 20.0, 23.0, 23.0, 17.0, 16.0, 16.0, 22.0, 21.0, 23.0, 20.0, 18.0, 19.0, 22.0, 20.0, 17.0, 20.0]
# [23.0, 20.0, 23.0, 23.0, 17.0, 16.0, 16.0, 22.0, 21.0, 23.0, 20.0, 18.0, 19.0, 22.0, 20.0, 17.0, 20.0, 19.0]
# [23.0, 20.0, 23.0, 23.0, 17.0, 16.0, 16.0, 22.0, 21.0, 23.0, 20.0, 18.0, 19.0, 22.0, 20.0, 17.0, 20.0, 19.0, 19.0]
# [23.0, 20.0, 23.0, 23.0, 17.0, 16.0, 16.0, 22.0, 21.0, 23.0, 20.0, 18.0, 19.0, 22.0, 20.0, 17.0, 20.0, 19.0, 19.0, 18.0]
# [23.0, 20.0, 23.0, 23.0, 17.0, 16.0, 16.0, 22.0, 21.0, 23.0, 20.0, 18.0, 19.0, 22.0, 20.0, 17.0, 20.0, 19.0, 19.0, 18.0, 21.0]
# [23.0, 20.0, 23.0, 23.0, 17.0, 16.0, 16.0, 22.0, 21.0, 23.0, 20.0, 18.0, 19.0, 22.0, 20.0, 17.0, 20.0, 19.0, 19.0, 18.0, 21.0, 17.0]
# [23.0, 20.0, 23.0, 23.0, 17.0, 16.0, 16.0, 22.0, 21.0, 23.0, 20.0, 18.0, 19.0, 22.0, 20.0, 17.0, 20.0, 19.0, 19.0, 18.0, 21.0, 17.0, 21.0]
# [23.0, 20.0, 23.0, 23.0, 17.0, 16.0, 16.0, 22.0, 21.0, 23.0, 20.0, 18.0, 19.0, 22.0, 20.0, 17.0, 20.0, 19.0, 19.0, 18.0, 21.0, 17.0, 21.0, 22.0]
# [23.0, 20.0, 23.0, 23.0, 17.0, 16.0, 16.0, 22.0, 21.0, 23.0, 20.0, 18.0, 19.0, 22.0, 20.0, 17.0, 20.0, 19.0, 19.0, 18.0, 21.0, 17.0, 21.0, 22.0, 20.0]
# [23.0, 20.0, 23.0, 23.0, 17.0, 16.0, 16.0, 22.0, 21.0, 23.0, 20.0, 18.0, 19.0, 22.0, 20.0, 17.0, 20.0, 19.0, 19.0, 18.0, 21.0, 17.0, 21.0, 22.0, 20.0, 18.0]
# [23.0, 20.0, 23.0, 23.0, 17.0, 16.0, 16.0, 22.0, 21.0, 23.0, 20.0, 18.0, 19.0, 22.0, 20.0, 17.0, 20.0, 19.0, 19.0, 18.0, 21.0, 17.0, 21.0, 22.0, 20.0, 18.0, 19.0]
# [23.0, 20.0, 23.0, 23.0, 17.0, 16.0, 16.0, 22.0, 21.0, 23.0, 20.0, 18.0, 19.0, 22.0, 20.0, 17.0, 20.0, 19.0, 19.0, 18.0, 21.0, 17.0, 21.0, 22.0, 20.0, 18.0, 19.0, 21.0]
# [23.0, 20.0, 23.0, 23.0, 17.0, 16.0, 16.0, 22.0, 21.0, 23.0, 20.0, 18.0, 19.0, 22.0, 20.0, 17.0, 20.0, 19.0, 19.0, 18.0, 21.0, 17.0, 21.0, 22.0, 20.0, 18.0, 19.0, 21.0, 16.0]
# [23.0, 20.0, 23.0, 23.0, 17.0, 16.0, 16.0, 22.0, 21.0, 23.0, 20.0, 18.0, 19.0, 22.0, 20.0, 17.0, 20.0, 19.0, 19.0, 18.0, 21.0, 17.0, 21.0, 22.0, 20.0, 18.0, 19.0, 21.0, 16.0, 22.0]

# %%
for s,b in zip(singers,bets):
    singers_map[s] = b

# %%
print(singers_map)
singers_map
# Out:
# {'alessandra amoroso': 23.0, 'alfa': 20.0, 'angelina mango': 23.0, 'annalisa': 23.0, 'bigmama': 17.0, 'bnkr44': 16.0, 'clara': 16.0, 'dargen d amico': 22.0, 'diodato': 21.0, 'emma': 23.0, 'fiorella mannoia': 20.0, 'fred de palma': 18.0, 'gazzelle': 19.0, 'geolier': 22.0, 'ghali': 20.0, 'il tre': 17.0, 'il volo': 20.0, 'irama': 19.0, 'la sad': 19.0, 'loredana berte': 18.0, 'mahmood': 21.0, 'maninni': 17.0, 'mr.rain': 21.0, 'negramaro': 22.0, 'renga e nek': 20.0, 'ricchi e poveri': 18.0, 'rose villain': 19.0, 'sangiovanni': 21.0, 'santi francesi': 16.0, 'the kolors': 22.0}
# {'alessandra amoroso': 23.0,
#  'alfa': 20.0,
#  'angelina mango': 23.0,
#  'annalisa': 23.0,
#  'bigmama': 17.0,
#  'bnkr44': 16.0,
#  'clara': 16.0,
#  'dargen d amico': 22.0,
#  'diodato': 21.0,
#  'emma': 23.0,
#  'fiorella mannoia': 20.0,
#  'fred de palma': 18.0,
#  'gazzelle': 19.0,
#  'geolier': 22.0,
#  'ghali': 20.0,
#  'il tre': 17.0,
#  'il volo': 20.0,
#  'irama': 19.0,
#  'la sad': 19.0,
#  'loredana berte': 18.0,
#  'mahmood': 21.0,
#  'maninni': 17.0,
#  'mr.rain': 21.0,
#  'negramaro': 22.0,
#  'renga e nek': 20.0,
#  'ricchi e poveri': 18.0,
#  'rose villain': 19.0,
#  'sangiovanni': 21.0,
#  'santi francesi': 16.0,
#  'the kolors': 22.0}

# %%
bets_map
# Out:
# defaultdict(list,
#             {"I p' me, tu p' te": [3.0, 4.0],
#              'fino a qui': [4.5, 4.0],
#              'sinceramente': [6.0, 7.0],
#              'ricominciamo tutto': [9.0, 11.0],
#              'la noia': [10.0, 7.5],
#              'capolavoro': [13.0, 16.0],
#              'tuta gold': [13.0, 11.0],
#              'ti muovi': [15.0, 16.0],
#              'tu no': [15.0, 16.0],
#              'apnea': [21.0, 21.0],
#              'diamanti grezzi': [26.0],
#              'mariposa': [26.0, 21.0],
#              'mr. rain': [26.0],
#              'un ragazzo una ragazza': [26.0, 21.0],
#              'casa mia': [31.0, 36.0],
#              'tutto qui': [34.0, 31.0],
#              'pazzo di te': [34.0, 36.0],
#              "l'amore in bocca": [34.0, 16.0],
#              'finiscimi': [41.0, 31.0],
#              'alfa': [51.0, 51.0],
#              'la rabbia non ti basta': [51.0],
#              'dargen d amico': [51.0, 36.0],
#              'fragili': [51.0, 101.0],
#              'pazza': [51.0, 71.0],
#              'click boom!': [51.0, 51.0],
#              'governo punk': [67.0],
#              'autodistruttivo': [67.0, 101.0],
#              'il cielo non ci vuole': [81.0, 51.0],
#              'maninni': [81.0, 101.0],
#              'ma non tutta la vita': [101.0, 101.0],
#              'mr rain': [26.0],
#              'big mama': [71.0]})

# %%
singers = []
costs = []
bets = []
scores = []

for k, v in singers_map.items():
    singers.append(k)
    print(singers)
    costs.append(v)
    print(costs)
    if len(bets_map[k]) > 0:
        current_bet = sum(bets_map[k]) / len(bets_map[k])
        print(current_bet)
        bets.append(current_bet)
        scores.append((1 / current_bet) / v)
    else:
        bets.append(0)
        scores.append(0)
# Out:
# ['alessandra amoroso']
# [23.0]
# ['alessandra amoroso', 'alfa']
# [23.0, 20.0]
# 51.0
# ['alessandra amoroso', 'alfa', 'angelina mango']
# [23.0, 20.0, 23.0]
# ['alessandra amoroso', 'alfa', 'angelina mango', 'annalisa']
# [23.0, 20.0, 23.0, 23.0]
# ['alessandra amoroso', 'alfa', 'angelina mango', 'annalisa', 'bigmama']
# [23.0, 20.0, 23.0, 23.0, 17.0]
# ['alessandra amoroso', 'alfa', 'angelina mango', 'annalisa', 'bigmama', 'bnkr44']
# [23.0, 20.0, 23.0, 23.0, 17.0, 16.0]
# ['alessandra amoroso', 'alfa', 'angelina mango', 'annalisa', 'bigmama', 'bnkr44', 'clara']
# [23.0, 20.0, 23.0, 23.0, 17.0, 16.0, 16.0]
# ['alessandra amoroso', 'alfa', 'angelina mango', 'annalisa', 'bigmama', 'bnkr44', 'clara', 'dargen d amico']
# [23.0, 20.0, 23.0, 23.0, 17.0, 16.0, 16.0, 22.0]
# 43.5
# ['alessandra amoroso', 'alfa', 'angelina mango', 'annalisa', 'bigmama', 'bnkr44', 'clara', 'dargen d amico', 'diodato']
# [23.0, 20.0, 23.0, 23.0, 17.0, 16.0, 16.0, 22.0, 21.0]
# ['alessandra amoroso', 'alfa', 'angelina mango', 'annalisa', 'bigmama', 'bnkr44', 'clara', 'dargen d amico', 'diodato', 'emma']
# [23.0, 20.0, 23.0, 23.0, 17.0, 16.0, 16.0, 22.0, 21.0, 23.0]
# ['alessandra amoroso', 'alfa', 'angelina mango', 'annalisa', 'bigmama', 'bnkr44', 'clara', 'dargen d amico', 'diodato', 'emma', 'fiorella mannoia']
# [23.0, 20.0, 23.0, 23.0, 17.0, 16.0, 16.0, 22.0, 21.0, 23.0, 20.0]
# ['alessandra amoroso', 'alfa', 'angelina mango', 'annalisa', 'bigmama', 'bnkr44', 'clara', 'dargen d amico', 'diodato', 'emma', 'fiorella mannoia', 'fred de palma']
# [23.0, 20.0, 23.0, 23.0, 17.0, 16.0, 16.0, 22.0, 21.0, 23.0, 20.0, 18.0]
# ['alessandra amoroso', 'alfa', 'angelina mango', 'annalisa', 'bigmama', 'bnkr44', 'clara', 'dargen d amico', 'diodato', 'emma', 'fiorella mannoia', 'fred de palma', 'gazzelle']
# [23.0, 20.0, 23.0, 23.0, 17.0, 16.0, 16.0, 22.0, 21.0, 23.0, 20.0, 18.0, 19.0]
# ['alessandra amoroso', 'alfa', 'angelina mango', 'annalisa', 'bigmama', 'bnkr44', 'clara', 'dargen d amico', 'diodato', 'emma', 'fiorella mannoia', 'fred de palma', 'gazzelle', 'geolier']
# [23.0, 20.0, 23.0, 23.0, 17.0, 16.0, 16.0, 22.0, 21.0, 23.0, 20.0, 18.0, 19.0, 22.0]
# ['alessandra amoroso', 'alfa', 'angelina mango', 'annalisa', 'bigmama', 'bnkr44', 'clara', 'dargen d amico', 'diodato', 'emma', 'fiorella mannoia', 'fred de palma', 'gazzelle', 'geolier', 'ghali']
# [23.0, 20.0, 23.0, 23.0, 17.0, 16.0, 16.0, 22.0, 21.0, 23.0, 20.0, 18.0, 19.0, 22.0, 20.0]
# ['alessandra amoroso', 'alfa', 'angelina mango', 'annalisa', 'bigmama', 'bnkr44', 'clara', 'dargen d amico', 'diodato', 'emma', 'fiorella mannoia', 'fred de palma', 'gazzelle', 'geolier', 'ghali', 'il tre']
# [23.0, 20.0, 23.0, 23.0, 17.0, 16.0, 16.0, 22.0, 21.0, 23.0, 20.0, 18.0, 19.0, 22.0, 20.0, 17.0]
# ['alessandra amoroso', 'alfa', 'angelina mango', 'annalisa', 'bigmama', 'bnkr44', 'clara', 'dargen d amico', 'diodato', 'emma', 'fiorella mannoia', 'fred de palma', 'gazzelle', 'geolier', 'ghali', 'il tre', 'il volo']
# [23.0, 20.0, 23.0, 23.0, 17.0, 16.0, 16.0, 22.0, 21.0, 23.0, 20.0, 18.0, 19.0, 22.0, 20.0, 17.0, 20.0]
# ['alessandra amoroso', 'alfa', 'angelina mango', 'annalisa', 'bigmama', 'bnkr44', 'clara', 'dargen d amico', 'diodato', 'emma', 'fiorella mannoia', 'fred de palma', 'gazzelle', 'geolier', 'ghali', 'il tre', 'il volo', 'irama']
# [23.0, 20.0, 23.0, 23.0, 17.0, 16.0, 16.0, 22.0, 21.0, 23.0, 20.0, 18.0, 19.0, 22.0, 20.0, 17.0, 20.0, 19.0]
# ['alessandra amoroso', 'alfa', 'angelina mango', 'annalisa', 'bigmama', 'bnkr44', 'clara', 'dargen d amico', 'diodato', 'emma', 'fiorella mannoia', 'fred de palma', 'gazzelle', 'geolier', 'ghali', 'il tre', 'il volo', 'irama', 'la sad']
# [23.0, 20.0, 23.0, 23.0, 17.0, 16.0, 16.0, 22.0, 21.0, 23.0, 20.0, 18.0, 19.0, 22.0, 20.0, 17.0, 20.0, 19.0, 19.0]
# ['alessandra amoroso', 'alfa', 'angelina mango', 'annalisa', 'bigmama', 'bnkr44', 'clara', 'dargen d amico', 'diodato', 'emma', 'fiorella mannoia', 'fred de palma', 'gazzelle', 'geolier', 'ghali', 'il tre', 'il volo', 'irama', 'la sad', 'loredana berte']
# [23.0, 20.0, 23.0, 23.0, 17.0, 16.0, 16.0, 22.0, 21.0, 23.0, 20.0, 18.0, 19.0, 22.0, 20.0, 17.0, 20.0, 19.0, 19.0, 18.0]
# ['alessandra amoroso', 'alfa', 'angelina mango', 'annalisa', 'bigmama', 'bnkr44', 'clara', 'dargen d amico', 'diodato', 'emma', 'fiorella mannoia', 'fred de palma', 'gazzelle', 'geolier', 'ghali', 'il tre', 'il volo', 'irama', 'la sad', 'loredana berte', 'mahmood']
# [23.0, 20.0, 23.0, 23.0, 17.0, 16.0, 16.0, 22.0, 21.0, 23.0, 20.0, 18.0, 19.0, 22.0, 20.0, 17.0, 20.0, 19.0, 19.0, 18.0, 21.0]
# ['alessandra amoroso', 'alfa', 'angelina mango', 'annalisa', 'bigmama', 'bnkr44', 'clara', 'dargen d amico', 'diodato', 'emma', 'fiorella mannoia', 'fred de palma', 'gazzelle', 'geolier', 'ghali', 'il tre', 'il volo', 'irama', 'la sad', 'loredana berte', 'mahmood', 'maninni']
# [23.0, 20.0, 23.0, 23.0, 17.0, 16.0, 16.0, 22.0, 21.0, 23.0, 20.0, 18.0, 19.0, 22.0, 20.0, 17.0, 20.0, 19.0, 19.0, 18.0, 21.0, 17.0]
# 91.0
# ['alessandra amoroso', 'alfa', 'angelina mango', 'annalisa', 'bigmama', 'bnkr44', 'clara', 'dargen d amico', 'diodato', 'emma', 'fiorella mannoia', 'fred de palma', 'gazzelle', 'geolier', 'ghali', 'il tre', 'il volo', 'irama', 'la sad', 'loredana berte', 'mahmood', 'maninni', 'mr.rain']
# [23.0, 20.0, 23.0, 23.0, 17.0, 16.0, 16.0, 22.0, 21.0, 23.0, 20.0, 18.0, 19.0, 22.0, 20.0, 17.0, 20.0, 19.0, 19.0, 18.0, 21.0, 17.0, 21.0]
# ['alessandra amoroso', 'alfa', 'angelina mango', 'annalisa', 'bigmama', 'bnkr44', 'clara', 'dargen d amico', 'diodato', 'emma', 'fiorella mannoia', 'fred de palma', 'gazzelle', 'geolier', 'ghali', 'il tre', 'il volo', 'irama', 'la sad', 'loredana berte', 'mahmood', 'maninni', 'mr.rain', 'negramaro']
# [23.0, 20.0, 23.0, 23.0, 17.0, 16.0, 16.0, 22.0, 21.0, 23.0, 20.0, 18.0, 19.0, 22.0, 20.0, 17.0, 20.0, 19.0, 19.0, 18.0, 21.0, 17.0, 21.0, 22.0]
# ['alessandra amoroso', 'alfa', 'angelina mango', 'annalisa', 'bigmama', 'bnkr44', 'clara', 'dargen d amico', 'diodato', 'emma', 'fiorella mannoia', 'fred de palma', 'gazzelle', 'geolier', 'ghali', 'il tre', 'il volo', 'irama', 'la sad', 'loredana berte', 'mahmood', 'maninni', 'mr.rain', 'negramaro', 'renga e nek']
# [23.0, 20.0, 23.0, 23.0, 17.0, 16.0, 16.0, 22.0, 21.0, 23.0, 20.0, 18.0, 19.0, 22.0, 20.0, 17.0, 20.0, 19.0, 19.0, 18.0, 21.0, 17.0, 21.0, 22.0, 20.0]
# ['alessandra amoroso', 'alfa', 'angelina mango', 'annalisa', 'bigmama', 'bnkr44', 'clara', 'dargen d amico', 'diodato', 'emma', 'fiorella mannoia', 'fred de palma', 'gazzelle', 'geolier', 'ghali', 'il tre', 'il volo', 'irama', 'la sad', 'loredana berte', 'mahmood', 'maninni', 'mr.rain', 'negramaro', 'renga e nek', 'ricchi e poveri']
# [23.0, 20.0, 23.0, 23.0, 17.0, 16.0, 16.0, 22.0, 21.0, 23.0, 20.0, 18.0, 19.0, 22.0, 20.0, 17.0, 20.0, 19.0, 19.0, 18.0, 21.0, 17.0, 21.0, 22.0, 20.0, 18.0]
# ['alessandra amoroso', 'alfa', 'angelina mango', 'annalisa', 'bigmama', 'bnkr44', 'clara', 'dargen d amico', 'diodato', 'emma', 'fiorella mannoia', 'fred de palma', 'gazzelle', 'geolier', 'ghali', 'il tre', 'il volo', 'irama', 'la sad', 'loredana berte', 'mahmood', 'maninni', 'mr.rain', 'negramaro', 'renga e nek', 'ricchi e poveri', 'rose villain']
# [23.0, 20.0, 23.0, 23.0, 17.0, 16.0, 16.0, 22.0, 21.0, 23.0, 20.0, 18.0, 19.0, 22.0, 20.0, 17.0, 20.0, 19.0, 19.0, 18.0, 21.0, 17.0, 21.0, 22.0, 20.0, 18.0, 19.0]
# ['alessandra amoroso', 'alfa', 'angelina mango', 'annalisa', 'bigmama', 'bnkr44', 'clara', 'dargen d amico', 'diodato', 'emma', 'fiorella mannoia', 'fred de palma', 'gazzelle', 'geolier', 'ghali', 'il tre', 'il volo', 'irama', 'la sad', 'loredana berte', 'mahmood', 'maninni', 'mr.rain', 'negramaro', 'renga e nek', 'ricchi e poveri', 'rose villain', 'sangiovanni']
# [23.0, 20.0, 23.0, 23.0, 17.0, 16.0, 16.0, 22.0, 21.0, 23.0, 20.0, 18.0, 19.0, 22.0, 20.0, 17.0, 20.0, 19.0, 19.0, 18.0, 21.0, 17.0, 21.0, 22.0, 20.0, 18.0, 19.0, 21.0]
# ['alessandra amoroso', 'alfa', 'angelina mango', 'annalisa', 'bigmama', 'bnkr44', 'clara', 'dargen d amico', 'diodato', 'emma', 'fiorella mannoia', 'fred de palma', 'gazzelle', 'geolier', 'ghali', 'il tre', 'il volo', 'irama', 'la sad', 'loredana berte', 'mahmood', 'maninni', 'mr.rain', 'negramaro', 'renga e nek', 'ricchi e poveri', 'rose villain', 'sangiovanni', 'santi francesi']
# [23.0, 20.0, 23.0, 23.0, 17.0, 16.0, 16.0, 22.0, 21.0, 23.0, 20.0, 18.0, 19.0, 22.0, 20.0, 17.0, 20.0, 19.0, 19.0, 18.0, 21.0, 17.0, 21.0, 22.0, 20.0, 18.0, 19.0, 21.0, 16.0]
# ['alessandra amoroso', 'alfa', 'angelina mango', 'annalisa', 'bigmama', 'bnkr44', 'clara', 'dargen d amico', 'diodato', 'emma', 'fiorella mannoia', 'fred de palma', 'gazzelle', 'geolier', 'ghali', 'il tre', 'il volo', 'irama', 'la sad', 'loredana berte', 'mahmood', 'maninni', 'mr.rain', 'negramaro', 'renga e nek', 'ricchi e poveri', 'rose villain', 'sangiovanni', 'santi francesi', 'the kolors']
# [23.0, 20.0, 23.0, 23.0, 17.0, 16.0, 16.0, 22.0, 21.0, 23.0, 20.0, 18.0, 19.0, 22.0, 20.0, 17.0, 20.0, 19.0, 19.0, 18.0, 21.0, 17.0, 21.0, 22.0, 20.0, 18.0, 19.0, 21.0, 16.0, 22.0]

# %%
list(zip(singers, costs, bets, scores))
# Out:
# [('alessandra amoroso', 23.0, 0, 0),
#  ('alfa', 20.0, 51.0, 0.000980392156862745),
#  ('angelina mango', 23.0, 0, 0),
#  ('annalisa', 23.0, 0, 0),
#  ('bigmama', 17.0, 0, 0),
#  ('bnkr44', 16.0, 0, 0),
#  ('clara', 16.0, 0, 0),
#  ('dargen d amico', 22.0, 43.5, 0.001044932079414838),
#  ('diodato', 21.0, 0, 0),
#  ('emma', 23.0, 0, 0),
#  ('fiorella mannoia', 20.0, 0, 0),
#  ('fred de palma', 18.0, 0, 0),
#  ('gazzelle', 19.0, 0, 0),
#  ('geolier', 22.0, 0, 0),
#  ('ghali', 20.0, 0, 0),
#  ('il tre', 17.0, 0, 0),
#  ('il volo', 20.0, 0, 0),
#  ('irama', 19.0, 0, 0),
#  ('la sad', 19.0, 0, 0),
#  ('loredana berte', 18.0, 0, 0),
#  ('mahmood', 21.0, 0, 0),
#  ('maninni', 17.0, 91.0, 0.0006464124111182936),
#  ('mr.rain', 21.0, 0, 0),
#  ('negramaro', 22.0, 0, 0),
#  ('renga e nek', 20.0, 0, 0),
#  ('ricchi e poveri', 18.0, 0, 0),
#  ('rose villain', 19.0, 0, 0),
#  ('sangiovanni', 21.0, 0, 0),
#  ('santi francesi', 16.0, 0, 0),
#  ('the kolors', 22.0, 0, 0)]

# %%
from pulp import LpProblem, LpMaximize, LpVariable, LpInteger


def maximization_scores(singers, costs, bets, scores):
    P = range(len(singers))
    # Declare problem instance, maximization problem
    prob = LpProblem("Portfolio", LpMaximize)
    # Declare decision variable x, which is 1 if a
    # singer is part of the portfolio and 0 else
    x = LpVariable.matrix("x", list(P), 0, 1, LpInteger)
    # Objective function -> Maximize scores
    prob += sum(scores[p] * x[p] for p in P)
    ### Constraint definition

    # constraint for the number of singers in the team
    prob += sum(x[p] for p in P) == 5
    # constraint on the total amount of credits
    prob += sum(costs[p] * x[p] for p in P) <= 100
    # constraint for having every player only once in the final team
    for elem in singers:
        prob += sum(x[p] for p in P if singers[p] == elem) <= 1
    # Start solving the problem instance
    prob.solve()
    # Extract solution
    portfolio = [(singers[p], costs[p], bets[p], scores[p]) for p in P if x[p].varValue]
    portfolio = sorted(portfolio, key=lambda x: x[3], reverse=True)
    return portfolio

# %%
portfolio = maximization_scores(singers, costs, bets, scores)

# %%
portfolio
# Out:
# [('dargen d amico', 22.0, 43.5, 0.001044932079414838),
#  ('alfa', 20.0, 51.0, 0.000980392156862745),
#  ('maninni', 17.0, 91.0, 0.0006464124111182936),
#  ('il tre', 17.0, 0, 0),
#  ('renga e nek', 20.0, 0, 0)]

# %%
sorted(list(zip(singers, costs, scores)), key=lambda x: x[2], reverse=True)
# Out:
# [('dargen d amico', 22.0, 0.001044932079414838),
#  ('alfa', 20.0, 0.000980392156862745),
#  ('maninni', 17.0, 0.0006464124111182936),
#  ('alessandra amoroso', 23.0, 0),
#  ('angelina mango', 23.0, 0),
#  ('annalisa', 23.0, 0),
#  ('bigmama', 17.0, 0),
#  ('bnkr44', 16.0, 0),
#  ('clara', 16.0, 0),
#  ('diodato', 21.0, 0),
#  ('emma', 23.0, 0),
#  ('fiorella mannoia', 20.0, 0),
#  ('fred de palma', 18.0, 0),
#  ('gazzelle', 19.0, 0),
#  ('geolier', 22.0, 0),
#  ('ghali', 20.0, 0),
#  ('il tre', 17.0, 0),
#  ('il volo', 20.0, 0),
#  ('irama', 19.0, 0),
#  ('la sad', 19.0, 0),
#  ('loredana berte', 18.0, 0),
#  ('mahmood', 21.0, 0),
#  ('mr.rain', 21.0, 0),
#  ('negramaro', 22.0, 0),
#  ('renga e nek', 20.0, 0),
#  ('ricchi e poveri', 18.0, 0),
#  ('rose villain', 19.0, 0),
#  ('sangiovanni', 21.0, 0),
#  ('santi francesi', 16.0, 0),
#  ('the kolors', 22.0, 0)]
